# %% [markdown]
# # Ontology Tools Experiment Notebook
#
# - This notebook contains experiments using the Ontology Tools.
#
# - Demo `transform_radlex()` function
#
#   1. Accessing the "ontologies" database in MongoDB.
#   2. Demo the `transform_radlex()` function on 1 JSON document.
#   3. Demo the `transform_radlex()` function on multiple JSON document.
#
# - Demo JSON dump using `batch_write_mongoDB` function
#
#   1. Demo 100 JSON documents dump.
#
# - Final Script in notebook
#   1. Run 100 document batches => write back to `radlex` collection in `ontologies` database within MongoDB.

# %%
# import local modules
# import MongoDB modules
import motor.motor_asyncio
from dotenv import dotenv_values
from openimagingdatamodel.ontology_tools import RadLexConcept, transform_radlex

# %%
# establish connection to MongoDB
config = dotenv_values(".env")
client = motor.motor_asyncio.AsyncIOMotorClient(config["ATLAS_DSN"])
db = client["ontologies"]
collection = db["radlex"]
# Get the count of documents in the collection to confirm that the data was loaded
count = await collection.count_documents({})
print(f"Count of documents in the collection: {count}")
# Out:
# Count of documents in the collection: 46761

# %%
# Access the ontologies database and "RadLex" collection
doc = await collection.find_one()

# %%
print(doc)
# Out:
# {'_id': 'RID38411', 'preferredLabel': 'postcentral branch of spinal branch of left third lumbar artery', 'parent': 'RID38409', 'radlexProperties': {'fmaid': '15206', 'preferredNameGerman': 'Ramus postcentralis des Ramus spinalis der linken Arteria lumbalis III'}}

# %%
concept = RadLexConcept.model_validate(doc)

# %%
print(concept.model_dump_json(indent=2, by_alias=True))
# Out:
# {
#   "_id": "RID38411",
#   "preferredLabel": "postcentral branch of spinal branch of left third lumbar artery",
#   "synonyms": null,
#   "parent": "RID38409",
#   "definition": null,
#   "radlexProperties": {
#     "fmaid": "15206",
#     "preferredNameGerman": "Ramus postcentralis des Ramus spinalis der linken Arteria lumbalis III"
#   }
# }

# %%
collection = db["snomedct"]
SNOMED_CT_COUNT = await collection.count_documents({})

# %%
import random

random_doc = await collection.find_one({}, skip=random.randint(0, SNOMED_CT_COUNT))
print(random_doc)
# Out:
# {'_id': '23381000087109', 'conceptId': '23381000087109', 'effectiveDate': '2018-07-31', 'modules': ['SNOMED-CT-core'], 'languageCode': 'en', 'preferredTerm': 'Structure of proximal interphalangeal joint of left little finger', 'terms': ['Proximal interphalangeal joint of left little finger', 'Proximal interphalangeal joint of fifth digit of left hand'], 'semanticTags': ['body structure'], 'caseSignificance': 'insensitive', 'definitions': None}

# %%
from pydantic import BaseModel, ConfigDict
from pydantic.alias_generators import to_camel


class SnomedCTConcept(BaseModel):
    model_config = ConfigDict(
        populate_by_name=True,
        coerce_numbers_to_str=True,
        alias_generator=to_camel,
        validate_assignment=True,
    )
    concept_id: str
    effective_date: str
    modules: list[str] | None = None
    language_code: str
    preferred_term: str
    terms: list[str] | None = None
    case_significance: str
    definitions: list[str] | None = None

# %%
doc = SnomedCTConcept.model_validate(random_doc)
print(doc.model_dump_json(indent=2, by_alias=True))
# Out:
# {
#   "conceptId": "23381000087109",
#   "effectiveDate": "2018-07-31",
#   "modules": [
#     "SNOMED-CT-core"
#   ],
#   "languageCode": "en",
#   "preferredTerm": "Structure of proximal interphalangeal joint of left little finger",
#   "terms": [
#     "Proximal interphalangeal joint of left little finger",
#     "Proximal interphalangeal joint of fifth digit of left hand"
#   ],
#   "caseSignificance": "insensitive",
#   "definitions": null
# }

# %%
class SnomedCTConceptRepo:
    def __init__(self, collection: motor.motor_asyncio.AsyncIOMotorCollection):
        self.collection = collection

    async def get_concept(self, concept_id: str) -> SnomedCTConcept:
        concept = await self.collection.find_one({"conceptId": concept_id})
        return SnomedCTConcept.model_validate(concept)

# %%
repo = SnomedCTConceptRepo(collection)

# %%
doc = await repo.get_concept("23381000087109")

# %%
doc.preferred_term
# Out:
# 'Structure of proximal interphalangeal joint of left little finger'

# %%
import motor.motor_asyncio

# Check if collection is of type motor.MotorCollection
if isinstance(collection, motor.MotorCollection):
    print("collection is of type motor.MotorCollection")
else:
    print("collection is not of type motor.MotorCollection")
# Out:
# collection is not of type motor.MotorCollection

# %% [markdown]
# ### Demo `transform_radlex()` function before writing to MongoDB

# %% [markdown]
# #### Demo function on 1 document

# %%
t_doc: RadLexConcept = transform_radlex(doc)
print(t_doc.model_dump_json(indent=2, by_alias=True, exclude_unset=True, exclude_none=True))
# Out:
# {
#   "_id": "RID38411",
#   "preferredLabel": "postcentral branch of spinal branch of left third lumbar artery",
#   "parent": "RID38409",
#   "radlexProperties": {
#     "fmaid": "15206",
#     "preferredNameGerman": "Ramus postcentralis des Ramus spinalis der linken Arteria lumbalis III"
#   }
# }

# %% [markdown]
# #### Demo function on multiple documents

# %%
# Check multiple documents
docs = await collection.find({}).to_list(length=100)
for doc in docs:
    t_doc = transform_radlex(doc)
    print(t_doc.model_dump_json(indent=2, by_alias=True, exclude_unset=True, exclude_none=True))
# Out:
# {
#   "_id": "RID38411",
#   "preferredLabel": "postcentral branch of spinal branch of left third lumbar artery",
#   "parent": "RID38409",
#   "radlexProperties": {
#     "fmaid": "15206",
#     "preferredNameGerman": "Ramus postcentralis des Ramus spinalis der linken Arteria lumbalis III"
#   }
# }
# {
#   "_id": "RID35591",
#   "preferredLabel": "string-of-pearls sign of bowel",
#   "parent": "RID29023",
#   "definition": "Oblique or horizontal row of air bubbles visible on abdominal radiograph; almost always indicates small bowel obstruction; air is trapped between valvulae conniventes along the superior wall of the intestine.",
#   "radlexProperties": {
#     "anatomicalSite": "RID132",
#     "comment": "157",
#     "mayBeCausedBy": "RID4962",
#     "preferredNameGerman": "string-of-pearls sign of bowel (EN)",
#     "relatedModality": "RID10345",
#     "source": "Radiology 2000; 214:157-158"
#   }
# }
# {
#   "_id": "RID22326",
#   "preferredLabel": "trunk of superficial transverse perineal muscle branch of perineal nerve",
#   "parent": "RID22325",
#   "radlexProperties": {
#     "fmaid": "78765",
#     "preferredNameGerman": "Truncus des Ramus des Nervus perinealis zum Musculus transversus perinei superficialis"
#   }
# }
# {
#   "_id": "RID4271",
#   "preferredLabel": "hepatocellular carcinoma",
#   "synonyms": [
#     "hepatoma",
#     "HCC"
#   ],
#   "parent": "RID4247",
#   "definition": "A primary malignant neoplasm of epithelial liver cells. It ranges from a well-differentiated tumor with epithelial cells indistinguishable from normal hepatocytes to a poorly differentiated neoplasm. The cells may be uniform or markedly pleomorphic, or form giant cells. Several classification schemes have been suggested. [MeSH]",
#   "radlexProperties": {
#     "acronym": "HCC",
#     "mayCause": "RID35633",
#     "preferredNameGerman": "Hepatozelluläres Karzinom",
#     "umlsId": "C0019204"
#   }
# }
# {
#   "_id": "RID46151",
#   "preferredLabel": "trunk of posterior division of brachial plexus branch of right first thoracic nerve",
#   "parent": "RID46150",
#   "radlexProperties": {
#     "fmaid": "305157",
#     "hasRegionalPart": [
#       "RID48068",
#       "RID48071"
#     ],
#     "preferredNameGerman": "Truncus des posterioren Teils des Ramus des rechten Nervus thoracicus I zum Plexus brachialis"
#   }
# }
# {
#   "_id": "RID41389",
#   "preferredLabel": "tendon of left second interspinalis lumborum",
#   "parent": "RID41387",
#   "radlexProperties": {
#     "fmaid": "223245",
#     "preferredNameGerman": "Sehne des linken Musculus interspinalis lumborum II"
#   }
# }
# {
#   "_id": "RID40345",
#   "preferredLabel": "muscle body of dorsal interosseous of right hand",
#   "parent": "RID40344",
#   "radlexProperties": {
#     "fmaid": "297676",
#     "preferredNameGerman": "Muskelkörper des Musculus interosseus dorsalis der rechten Hand"
#   }
# }
# {
#   "_id": "RID14646",
#   "preferredLabel": "lingual branch of left glossopharyngeal nerve to left postsulcal part of tongue",
#   "parent": "RID14644",
#   "radlexProperties": {
#     "branchOf": "RID27699",
#     "fmaid": "53522",
#     "preferredNameGerman": "Ramus lingualis des linken Nervus glossopharyngeus zum linken Teil der Zungenwurzel",
#     "regionalPartOf": "RID27699"
#   }
# }
# {
#   "_id": "RID38548",
#   "preferredLabel": "posterior branch of lateral cutaneous branch of ventral branch of lumbar artery",
#   "parent": "RID38519",
#   "radlexProperties": {
#     "fmaid": "15335",
#     "preferredNameGerman": "Ramus posterior des Ramus cutaneus lateralis des Ramus ventralis der Arteria lumbalis",
#     "regionalPartOf": "RID38520"
#   }
# }
# {
#   "_id": "RID46248",
#   "preferredLabel": "lateral pectoral nerve branch of anterior division of anterior ramus of left fifth cervical nerve",
#   "parent": "RID46246",
#   "radlexProperties": {
#     "fmaid": "307455",
#     "preferredNameGerman": "Ramus des Nervus pectoralis lateralis des anterioren Teils des Ramus anterior des linken Nervus cervicalis V"
#   }
# }
# {
#   "_id": "RID21647",
#   "preferredLabel": "trunk of branch of internal laryngeal nerve",
#   "parent": "RID21624",
#   "radlexProperties": {
#     "fmaid": "80654",
#     "preferredNameGerman": "Truncus des Ramus des Nervus laryngeus internus"
#   }
# }
# {
#   "_id": "RID33917",
#   "preferredLabel": "sulcal segment of gyrus of right dentate gyrus",
#   "parent": "RID33916",
#   "radlexProperties": {
#     "fmaid": "275774",
#     "preferredNameGerman": "zum Sulcus gehörendes Segment des Gyrus des rechten Gyrus dentatus"
#   }
# }
# {
#   "_id": "RID40545",
#   "preferredLabel": "belly of extensor digitorum brevis",
#   "synonyms": [
#     "extensor digitorum brevis belly",
#     "muscle body proper of extensor digitorum brevis"
#   ],
#   "parent": "RID39492",
#   "radlexProperties": {
#     "fmaid": "51177",
#     "preferredNameGerman": "Bauch des Musculus extensor digitorum brevis"
#   }
# }
# {
#   "_id": "RID18846",
#   "preferredLabel": "root of eighth thoracic nerve",
#   "synonyms": [
#     "eighth thoracic neural root"
#   ],
#   "parent": "RID18824",
#   "radlexProperties": {
#     "fmaid": "22124",
#     "preferredNameGerman": "Wurzel des Nervus thoracicus VIII"
#   }
# }
# {
#   "_id": "RID39383",
#   "preferredLabel": "articular part of bone organ",
#   "parent": "RID13391",
#   "radlexProperties": {
#     "fmaid": "225625",
#     "preferredNameGerman": "Gelenkfläche des Knochens"
#   }
# }
# {
#   "_id": "RID45725",
#   "preferredLabel": "chondroid",
#   "parent": "RID6041",
#   "radlexProperties": {
#     "preferredNameGerman": "chondroid",
#     "source": "LID"
#   }
# }
# {
#   "_id": "RID43602",
#   "preferredLabel": "Beclere view",
#   "synonyms": [
#     "Beclere"
#   ],
#   "parent": "RID43598",
#   "radlexProperties": {
#     "preferredNameGerman": "Aufnahme nach Béclère"
#   }
# }
# {
#   "_id": "RID50014",
#   "preferredLabel": "thyroid tubercle",
#   "parent": "RID50013",
#   "radlexProperties": {
#     "created": "2016-05-23T00:00:00",
#     "preferredNameGerman": "hinteres Horn der Schilddrüse",
#     "radlexVersionOfClassChange": "3.14",
#     "regionalPartOf": "RID7578"
#   }
# }
# {
#   "_id": "RID19482",
#   "preferredLabel": "neuronal component of L2 segment",
#   "parent": "RID19480",
#   "radlexProperties": {
#     "fmaid": "267967",
#     "partOf": "RID19454",
#     "preferredNameGerman": "neuronale Komponente des Rückenmarkssegments L2"
#   }
# }
# {
#   "_id": "RID40267",
#   "preferredLabel": "muscle body of left flexor digitorum superficialis",
#   "parent": "RID40265",
#   "radlexProperties": {
#     "fmaid": "297762",
#     "preferredNameGerman": "Muskelkörper des linken Musculus flexor digitorum superficialis"
#   }
# }
# {
#   "_id": "RID27469",
#   "preferredLabel": "l4 segment of left ventral gray column of spinal cord",
#   "parent": "RID27467",
#   "radlexProperties": {
#     "fmaid": "267436",
#     "preferredNameGerman": "Segment L4 der linken Vordersäule des Rückenmarks"
#   }
# }
# {
#   "_id": "RID37008",
#   "preferredLabel": "internal pyramidal lamina of right Brodmann area 12",
#   "parent": "RID37007",
#   "radlexProperties": {
#     "fmaid": "283333",
#     "preferredNameGerman": "innere Pyramidenzellschicht des rechten Brodmann-Areals 12"
#   }
# }
# {
#   "_id": "RID16983",
#   "preferredLabel": "rostrum of right half of corpus callosum",
#   "parent": "RID16978",
#   "radlexProperties": {
#     "fmaid": "261105",
#     "partOf": "RID16979",
#     "preferredNameGerman": "Rostrum corporis callosi",
#     "regionalPartOf": "RID16979"
#   }
# }
# {
#   "_id": "RID25803",
#   "preferredLabel": "gray matter of posterior lobule of insula",
#   "parent": "RID25799",
#   "radlexProperties": {
#     "fmaid": "274853",
#     "preferredNameGerman": "graue Substanz des posterioren Anteils der Insula"
#   }
# }
# {
#   "_id": "RID2175",
#   "preferredLabel": "fascia of extensor compartment of forearm",
#   "parent": "RID2172",
#   "radlexProperties": {
#     "partOf": "RID2107",
#     "preferredNameGerman": "Unterarmfaszie des Extensorenkompartimentes"
#   }
# }
# {
#   "_id": "RID2177",
#   "preferredLabel": "wrist",
#   "synonyms": [
#     "carpus",
#     "Handgelenk"
#   ],
#   "parent": "RID28464",
#   "definition": "The region of the upper limb between the metacarpus and the forearm. [MeSH]",
#   "radlexProperties": {
#     "hasConstitutionalPart": "RID49945",
#     "hasPart": [
#       "RID2210",
#       "RID2240",
#       "RID2221",
#       "RID2307",
#       "RID2308",
#       "RID2195",
#       "RID2198",
#       "RID2192",
#       "RID2191",
#       "RID2193",
#       "RID2197",
#       "RID2280",
#       "RID2287",
#       "RID2264",
#       "RID2265",
#       "RID2267",
#       "RID2266",
#       "RID2268",
#       "RID2261",
#       "RID2260",
#       "RID2263",
#       "RID2299",
#       "RID2202",
#       "RID2203",
#       "RID2272",
#       "RID2279",
#       "RID2275",
#       "RID2311",
#       "RID2310",
#       "RID2314",
#       "RID2313",
#       "RID2316",
#       "RID2187",
#       "RID2181",
#       "RID2189",
#       "RID2180",
#       "RID2259",
#       "RID2256",
#       "RID2257"
#     ],
#     "partOf": "RID1850",
#     "preferredNameGerman": "carpus",
#     "source": "Playbook",
#     "synonymGerman": "Handgelenk",
#     "umlsId": "C0043262"
#   }
# }
# {
#   "_id": "RID2173",
#   "preferredLabel": "antebrachial fascia",
#   "parent": "RID2172",
#   "radlexProperties": {
#     "partOf": "RID2107",
#     "preferredNameGerman": "Fascia antebrachii"
#   }
# }
# {
#   "_id": "RID2179",
#   "preferredLabel": "RID2179",
#   "parent": "RID15849",
#   "radlexProperties": {
#     "comment": "not relevant; these are hand bones",
#     "preferredNameForObsolete": "bones of wrist"
#   }
# }
# {
#   "_id": "RID36892",
#   "preferredLabel": "internal granular layer of left Brodmann area 6",
#   "parent": "RID36890",
#   "radlexProperties": {
#     "fmaid": "283191",
#     "preferredNameGerman": "innere Körnerschicht des linken Brodmann-Areals 6"
#   }
# }
# {
#   "_id": "RID48937",
#   "preferredLabel": "skin of lateral part of third toe",
#   "parent": "RID48930",
#   "radlexProperties": {
#     "fmaid": "38205",
#     "preferredNameGerman": "Haut des lateralen Teils des dritten Zehs",
#     "regionalPartOf": "RID48678"
#   }
# }
# {
#   "_id": "RID21200",
#   "preferredLabel": "nucleus of origin of sixth thoracic spinal nerve",
#   "synonyms": [
#     "t6 nucleus of origin"
#   ],
#   "parent": "RID21184",
#   "radlexProperties": {
#     "fmaid": "80386",
#     "preferredNameGerman": "Ursprungskern des thorakalen Spinalnervs VI"
#   }
# }
# {
#   "_id": "RID50391",
#   "preferredLabel": "I-123 metaiodobenzylguanidine",
#   "parent": "RID43384",
#   "radlexProperties": {
#     "created": "2018-03-13T00:00:00",
#     "preferredNameGerman": "I-123 Metaiodobenzylguanidin",
#     "radlexVersionOfClassChange": "3.15",
#     "source": "LOINC"
#   }
# }
# {
#   "_id": "RID17673",
#   "preferredLabel": "left spinal trigeminal tract of pons",
#   "parent": "RID17671",
#   "radlexProperties": {
#     "fmaid": "73639",
#     "preferredNameGerman": "linker Tractus spinalis nervi trigemini"
#   }
# }
# {
#   "_id": "RID23956",
#   "preferredLabel": "branch of posterior ramus of sixth cervical nerve",
#   "parent": "RID23891",
#   "radlexProperties": {
#     "fmaid": "72083",
#     "preferredNameGerman": "Ramus des Ramus posterior des Nervus cervicalis VI"
#   }
# }
# {
#   "_id": "RID21692",
#   "preferredLabel": "trunk of muscular branch of left recurrent laryngeal nerve",
#   "parent": "RID21690",
#   "radlexProperties": {
#     "fmaid": "80699",
#     "preferredNameGerman": "Truncus des Ramus muscularis des linken Nervus laryngeus recurrens"
#   }
# }
# {
#   "_id": "RID34136",
#   "preferredLabel": "outer molecular layer of left dentate gyrus",
#   "parent": "RID34134",
#   "radlexProperties": {
#     "fmaid": "277826",
#     "preferredNameGerman": "äußere Molekularschicht des linken Gyrus dentatus"
#   }
# }
# {
#   "_id": "RID35145",
#   "preferredLabel": "dilated transverse colon sign",
#   "parent": "RID29023",
#   "definition": "Dilated transverse colon with empty cecum and ascending colon on a frontal radiograph. Suggests appendicitis, often with perforated appendix.",
#   "radlexProperties": {
#     "anatomicalSite": "RID159",
#     "mayBeCausedBy": "RID3383",
#     "preferredNameGerman": "dilated transverse colon sign (EN)",
#     "relatedModality": "RID10345",
#     "source": "Eisenberg, Ronald L. Atlas of Signs in Radiology."
#   }
# }
# {
#   "_id": "RID44880",
#   "preferredLabel": "suprasternal branch of suprascapular artery",
#   "synonyms": [
#     "suprasternal part of suprascapular artery"
#   ],
#   "parent": "RID44866",
#   "radlexProperties": {
#     "fmaid": "22601",
#     "preferredNameGerman": "Ramus suprasternalis der Arteria suprascapularis"
#   }
# }
# {
#   "_id": "RID5909",
#   "preferredLabel": "serpiginous",
#   "parent": "RID5863",
#   "radlexProperties": {
#     "preferredNameGerman": "serpiginös"
#   }
# }
# {
#   "_id": "RID5907",
#   "preferredLabel": "septated",
#   "synonyms": [
#     "septate"
#   ],
#   "parent": "RID5863",
#   "radlexProperties": {
#     "preferredNameGerman": "septiert"
#   }
# }
# {
#   "_id": "RID44508",
#   "preferredLabel": "muscle body of rectus femoris",
#   "synonyms": [
#     "muscle body of rectus femoris muscle"
#   ],
#   "parent": "RID40190",
#   "radlexProperties": {
#     "constitutionalPartOf": "RID2698",
#     "fmaid": "301255",
#     "hasRegionalPart": [
#       "RID44534",
#       "RID44537"
#     ],
#     "preferredNameGerman": "Muskelkörper des Musculus rectus femoris"
#   }
# }
# {
#   "_id": "RID45139",
#   "preferredLabel": "right radial recurrent artery",
#   "parent": "RID45138",
#   "radlexProperties": {
#     "fmaid": "22764",
#     "preferredNameGerman": "rechte Arteria radialis recurrens"
#   }
# }
# {
#   "_id": "RID26498",
#   "preferredLabel": "subgyral segment of left parietal lobe",
#   "parent": "RID26496",
#   "radlexProperties": {
#     "fmaid": "273282",
#     "preferredNameGerman": "subgyrales Segment des linken Parietallappens"
#   }
# }
# {
#   "_id": "RID40910",
#   "preferredLabel": "cleland ligament of right ring finger",
#   "parent": "RID40909",
#   "radlexProperties": {
#     "fmaid": "43552",
#     "preferredNameGerman": "Cleland-Band des rechten Ringfingers"
#   }
# }
# {
#   "_id": "RID18661",
#   "preferredLabel": "anterior root of left tenth thoracic nerve",
#   "parent": "RID18659",
#   "radlexProperties": {
#     "fmaid": "12943",
#     "partOf": "RID19718",
#     "preferredNameGerman": "Radix anterior des linken Nervus thoracicus X",
#     "regionalPartOf": [
#       "RID19718",
#       "RID44091"
#     ]
#   }
# }
# {
#   "_id": "RID48562",
#   "preferredLabel": "deep part of tendon of right quadriceps femoris",
#   "parent": "RID48561",
#   "radlexProperties": {
#     "fmaid": "51931",
#     "preferredNameGerman": "tiefer Teil der Sehne des rechten Musculus quadriceps femoris",
#     "regionalPartOf": "RID48532"
#   }
# }
# {
#   "_id": "RID39070",
#   "preferredLabel": "disrupted",
#   "synonyms": [
#     "unterbrochen"
#   ],
#   "parent": "RID5817",
#   "radlexProperties": {
#     "preferredNameGerman": "gestört",
#     "synonymGerman": "unterbrochen"
#   }
# }
# {
#   "_id": "RID35666",
#   "preferredLabel": "tumbling bullet sign",
#   "parent": "RID29023",
#   "definition": "A bullet that assumes different positions on serial radiographs.  If in abdomen, suggests location within abscess.  If in bone, indicates a traumatic bone cyst.",
#   "radlexProperties": {
#     "mayBeCausedBy": [
#       "RID3894",
#       "RID3711"
#     ],
#     "preferredNameGerman": "tumbling bullet sign (EN)",
#     "relatedModality": "RID10345",
#     "source": "Eisenberg, Ronald L. Atlas of Signs in Radiology;  http://www.gentili.net/signs/35.htm"
#   }
# }
# {
#   "_id": "RID25321",
#   "preferredLabel": "posterior branch of lateral cutaneous branch of seventh intercostal nerve",
#   "parent": "RID25308",
#   "radlexProperties": {
#     "branchOf": "RID23302",
#     "fmaid": "8877",
#     "preferredNameGerman": "Ramus posterior des Ramus cutaneus lateralis des Nervus intercostalis VII",
#     "regionalPartOf": "RID23302"
#   }
# }
# {
#   "_id": "RID33131",
#   "preferredLabel": "subperitoneal pelvic connective tissue",
#   "synonyms": [
#     "fascia extraperitonealis pelvis"
#   ],
#   "parent": "RID33121",
#   "radlexProperties": {
#     "fmaid": "19101",
#     "hasRegionalPart": [
#       "RID388",
#       "RID33167",
#       "RID33168",
#       "RID386",
#       "RID33154",
#       "RID33150",
#       "RID33155",
#       "RID33162",
#       "RID392",
#       "RID33143",
#       "RID33163",
#       "RID33152",
#       "RID33149",
#       "RID33160",
#       "RID33153",
#       "RID33161",
#       "RID33164",
#       "RID33151",
#       "RID33156",
#       "RID33165",
#       "RID33166"
#     ],
#     "preferredNameGerman": "fascia extraperitonealis pelvis",
#     "regionalPartOf": "RID33118"
#   }
# }
# {
#   "_id": "RID40251",
#   "preferredLabel": "muscle body of left triceps brachii",
#   "parent": "RID40249",
#   "radlexProperties": {
#     "fmaid": "297588",
#     "preferredNameGerman": "Muskelkörper des linken Musculus triceps brachii"
#   }
# }
# {
#   "_id": "RID25225",
#   "preferredLabel": "medial branch of anterior cutaneous branch of right eighth intercostal nerve",
#   "parent": "RID25224",
#   "radlexProperties": {
#     "branchOf": "RID23271",
#     "fmaid": "11395",
#     "preferredNameGerman": "Ramus medialis des Ramus cutaneus anterior des rechten Nervus intercostalis VIII",
#     "regionalPartOf": "RID23271"
#   }
# }
# {
#   "_id": "RID40657",
#   "preferredLabel": "belly of left omohyoid",
#   "synonyms": [
#     "left omohyoid belly"
#   ],
#   "parent": "RID40655",
#   "radlexProperties": {
#     "fmaid": "46339",
#     "preferredNameGerman": "Bauch des linken Musculus omohyoideus"
#   }
# }
# {
#   "_id": "RID15236",
#   "preferredLabel": "lateral muscular branch of radial nerve to brachialis",
#   "synonyms": [
#     "branch of radial nerve to lateral part of brachialis"
#   ],
#   "parent": "RID15235",
#   "radlexProperties": {
#     "branchOf": "RID7257",
#     "continuousWith": "RID22067",
#     "distalTo": "RID22067",
#     "fmaid": "65333",
#     "innervates": "RID2005",
#     "preferredNameGerman": "Ramus muscularis lateralis des Nervus radialis zum Musculus brachialis",
#     "regionalPartOf": "RID7257"
#   }
# }
# {
#   "_id": "RID23188",
#   "preferredLabel": "c6 branch to right scalenus minimus",
#   "synonyms": [
#     "scalenus minimus branch of right sixth cervical nerve"
#   ],
#   "parent": "RID23187",
#   "radlexProperties": {
#     "branchOf": "RID22787",
#     "fmaid": "65878",
#     "preferredNameGerman": "Ramus des Segments C6 zum rechten Musculus scalenus minimus",
#     "regionalPartOf": "RID22787"
#   }
# }
# {
#   "_id": "RID34884",
#   "preferredLabel": "umbilical vein",
#   "parent": "RID34883",
#   "radlexProperties": {
#     "preferredNameGerman": "Umbilikalvene"
#   }
# }
# {
#   "_id": "RID49970",
#   "preferredLabel": "set of ovarian vessels",
#   "synonyms": [
#     "blood vessels of ovary",
#     "ovarian vessels"
#   ],
#   "parent": "RID39545",
#   "radlexProperties": {
#     "constitutionalPartOf": "RID290",
#     "created": "2016-03-14T00:00:00",
#     "preferredNameGerman": "Menge von ovariellen Gefäße",
#     "radlexVersionOfClassChange": "3.14",
#     "source": "LOINC"
#   }
# }
# {
#   "_id": "RID26084",
#   "preferredLabel": "brodmann area 23 of left cingulate gyrus",
#   "parent": "RID26082",
#   "radlexProperties": {
#     "fmaid": "271768",
#     "partOf": [
#       "RID20369",
#       "RID25853"
#     ],
#     "preferredNameGerman": "Brodmann-Areal 23 des linken Gyrus cinguli",
#     "regionalPartOf": [
#       "RID20369",
#       "RID25853"
#     ],
#     "talairach": "934"
#   }
# }
# {
#   "_id": "RID37469",
#   "preferredLabel": "lamina of Brodmann area 37",
#   "parent": "RID36783",
#   "radlexProperties": {
#     "fmaid": "282397",
#     "preferredNameGerman": "Lamina des Brodmann-Areals 37"
#   }
# }
# {
#   "_id": "RID9743",
#   "preferredLabel": "inferior tarsal plate of eyelid",
#   "synonyms": [
#     "inferior tarsus of eyelid"
#   ],
#   "parent": "RID13287",
#   "radlexProperties": {
#     "partOf": "RID9729",
#     "preferredNameGerman": "Tarsus inferior"
#   }
# }
# {
#   "_id": "RID9741",
#   "preferredLabel": "superior tarsal plate of eyelid",
#   "synonyms": [
#     "superior tarsus of eyelid"
#   ],
#   "parent": "RID13287",
#   "radlexProperties": {
#     "partOf": "RID9729",
#     "preferredNameGerman": "Tarsus superior"
#   }
# }
# {
#   "_id": "RID25925",
#   "preferredLabel": "brodmann area 2 of right parietal lobe",
#   "parent": "RID25924",
#   "radlexProperties": {
#     "fmaid": "273733",
#     "hasPart": [
#       "RID25919",
#       "RID25922"
#     ],
#     "hasRegionalPart": [
#       "RID25919",
#       "RID25922"
#     ],
#     "preferredNameGerman": "Brodmann-Areal 2 des rechten Parietallappens"
#   }
# }
# {
#   "_id": "RID12205",
#   "preferredLabel": "esophageal branch of recurrent laryngeal nerve",
#   "parent": "RID14758",
#   "radlexProperties": {
#     "branchOf": "RID12203",
#     "fmaid": "6248",
#     "memberOf": "RID13190",
#     "partOf": "RID13190",
#     "preferredNameGerman": "Ramus esophageus des Nervus laryngeus recurrens",
#     "regionalPartOf": "RID12203"
#   }
# }
# {
#   "_id": "RID26629",
#   "preferredLabel": "polar part of inferior occipital gyrus",
#   "parent": "RID26622",
#   "radlexProperties": {
#     "fmaid": "274593",
#     "partOf": "RID20418",
#     "preferredNameGerman": "polarer Teil des Gyrus occipitalis inferior",
#     "regionalPartOf": "RID20418"
#   }
# }
# {
#   "_id": "RID27188",
#   "preferredLabel": "s2 segment of nucleus proprius of spinal cord",
#   "parent": "RID27184",
#   "radlexProperties": {
#     "fmaid": "257892",
#     "partOf": "RID27367",
#     "preferredNameGerman": "Segment S2 des Nucleus proprius des Rückenmarks",
#     "regionalPartOf": "RID27367"
#   }
# }
# {
#   "_id": "RID33814",
#   "preferredLabel": "orbital part of right middle frontal gyrus",
#   "parent": "RID33813",
#   "radlexProperties": {
#     "aal": "10",
#     "fmaid": "278609",
#     "preferredNameGerman": "Pars orbitalis des rechten Gyrus frontalis medius"
#   }
# }
# {
#   "_id": "RID10188",
#   "preferredLabel": "stapedius",
#   "parent": "RID10185",
#   "definition": "The stapedius muscle arises from the wall of the middle ear and is inserted into the neck of the stapes. Its action is to pull the head of the stapes backward. [MeSH]",
#   "radlexProperties": {
#     "preferredNameGerman": "Musculus stapedius",
#     "umlsId": "C0038151"
#   }
# }
# {
#   "_id": "RID4279",
#   "preferredLabel": "transitional cell carcinoma",
#   "synonyms": [
#     "TCC"
#   ],
#   "parent": "RID4247",
#   "definition": "A malignant neoplasm derived from transitional epithelium, occurring chiefly in the urinary bladder, ureters or renal pelves (especially if well differentiated), frequently papillary. Transitional cell carcinomas are graded 1 to 3 or 4 according to the degree of anaplasia, grade 1 appearing histologically benign but being liable to recurrence. (Stedman, 25th ed) [MeSH]",
#   "radlexProperties": {
#     "mayCause": "RID35081",
#     "preferredNameGerman": "Transitionalzellkarzinom",
#     "umlsId": "C0007138"
#   }
# }
# {
#   "_id": "RID4273",
#   "preferredLabel": "fibrolamellar hepatocellular carcinoma",
#   "parent": "RID4271",
#   "radlexProperties": {
#     "preferredNameGerman": "fibrolamelläres hepatozelluläres Karzinom"
#   }
# }
# {
#   "_id": "RID4278",
#   "preferredLabel": "thymoma",
#   "parent": "RID4210",
#   "definition": "A neoplasm originating from thymic tissue, usually benign, and frequently encapsulated. Although it is occasionally invasive, metastases are extremely rare. It consists of any type of thymic epithelial cell as well as lymphocytes that are usually abundant and probably not neoplastic. Malignant lymphomas that involve the thymus, e.g., lymphosarcoma, Hodgkin's disease (previously termed granulomatous thymoma), should not be regarded as thymoma. (Stedman, 25th ed) [MeSH]",
#   "radlexProperties": {
#     "mayCause": "RID35524",
#     "preferredNameGerman": "Thymom",
#     "umlsId": "C0040100"
#   }
# }
# {
#   "_id": "RID19546",
#   "preferredLabel": "neuronal component of white matter of cervical segment of spinal cord",
#   "parent": "RID19545",
#   "radlexProperties": {
#     "constitutionalPartOf": [
#       "RID18165",
#       "RID34070"
#     ],
#     "fmaid": "268071",
#     "hasPart": [
#       "RID19553",
#       "RID19558",
#       "RID19555",
#       "RID19557",
#       "RID19556",
#       "RID19554",
#       "RID19559",
#       "RID19560"
#     ],
#     "hasRegionalPart": [
#       "RID19553",
#       "RID19558",
#       "RID19555",
#       "RID19557",
#       "RID19556",
#       "RID19554",
#       "RID19559",
#       "RID19560"
#     ],
#     "partOf": "RID18165",
#     "preferredNameGerman": "neuronale Komponente der weißen Substanz eines zervikalen Rückenmarkssegments"
#   }
# }
# {
#   "_id": "RID29089",
#   "preferredLabel": "trochlea of talus",
#   "parent": "RID6111",
#   "radlexProperties": {
#     "preferredNameGerman": "Trochlea des Talus",
#     "regionalPartOf": "RID2949"
#   }
# }
# {
#   "_id": "RID31945",
#   "preferredLabel": "juxta-arterial ileal lymph node group",
#   "synonyms": [
#     "juxta-arterial ileal lymph nodes",
#     "set of juxta-arterial ileal lymph nodes"
#   ],
#   "parent": "RID31968",
#   "radlexProperties": {
#     "constitutionalPartOf": "RID29714",
#     "drainsInto": "RID31971",
#     "fmaid": "277631",
#     "memberOf": [
#       "RID31954",
#       "RID31943"
#     ],
#     "preferredNameGerman": "juxta-arterielle Lymphknotengruppe des Ileums",
#     "receivesDrainageFrom": [
#       "RID31948",
#       "RID31951"
#     ]
#   }
# }
# {
#   "_id": "RID41026",
#   "preferredLabel": "left glenoid labrum",
#   "parent": "RID1909",
#   "radlexProperties": {
#     "constitutionalPartOf": "RID42241",
#     "fmaid": "23292",
#     "hasRegionalPart": [
#       "RID42703",
#       "RID42698",
#       "RID42701",
#       "RID42704",
#       "RID42695"
#     ],
#     "preferredNameGerman": "linkes Labrum glenoidale"
#   }
# }
# {
#   "_id": "RID40800",
#   "preferredLabel": "distal region of muscle body of deltoid",
#   "synonyms": [
#     "distal muscle body region of deltoid",
#     "distal muscle body region of deltoid muscle"
#   ],
#   "parent": "RID40784",
#   "radlexProperties": {
#     "constitutionalPartOf": "RID43220",
#     "continuousWith": [
#       "RID40745",
#       "RID41053"
#     ],
#     "fmaid": "298863",
#     "hasRegionalPart": [
#       "RID40807",
#       "RID40813",
#       "RID40810"
#     ],
#     "preferredNameGerman": "distale Region des Muskelbauchs des Musculus deltoideus"
#   }
# }
# {
#   "_id": "RID35757",
#   "preferredLabel": "subdivision of surface of skull",
#   "parent": "RID29526",
#   "radlexProperties": {
#     "preferredNameGerman": "Segment der Oberfläche des Schädels"
#   }
# }
# {
#   "_id": "RID20512",
#   "preferredLabel": "magnocellular layer of dorsal nucleus of lateral geniculate body",
#   "synonyms": [
#     "strata magnocellularia nuclei dorsalis corporis geniculati lateralis"
#   ],
#   "parent": "RID33996",
#   "radlexProperties": {
#     "fmaid": "76989",
#     "preferredNameGerman": "strata magnocellularia nuclei dorsalis corporis geniculati lateralis"
#   }
# }
# {
#   "_id": "RID36599",
#   "preferredLabel": "branch of left anterior choroidal artery to hypothalamus",
#   "parent": "RID36597",
#   "radlexProperties": {
#     "fmaid": "66416",
#     "preferredNameGerman": "Ramus der linken Arteria choroidea anterior zum Hypothalamus"
#   }
# }
# {
#   "_id": "RID44968",
#   "preferredLabel": "deltoid branch of right thoraco-acromial artery",
#   "synonyms": [
#     "deltoid part of right thoraco-acromial artery"
#   ],
#   "parent": "RID44967",
#   "radlexProperties": {
#     "fmaid": "23072",
#     "preferredNameGerman": "Ramus deltoideus der rechten Arteria thoracoacromialis"
#   }
# }
# {
#   "_id": "RID16467",
#   "preferredLabel": "set of rootlets of sixth thoracic nerve",
#   "parent": "RID16461",
#   "radlexProperties": {
#     "fmaid": "79706",
#     "preferredNameGerman": "Gruppe der Wurzelfasern des Nervus thoracicus VI"
#   }
# }
# {
#   "_id": "RID47283",
#   "preferredLabel": "median nerve component of inferior trunk segment of right first thoracic nerve",
#   "synonyms": [
#     "median nerve component of inferior trunk segment of right T1"
#   ],
#   "parent": "RID47282",
#   "radlexProperties": {
#     "continuousWith": [
#       "RID47277",
#       "RID47280"
#     ],
#     "distalTo": "RID47277",
#     "fmaid": "307675",
#     "preferredNameGerman": "zum Nervus medianus gehörender Teil des zum rechten Nervus thoracicus I gehörenden Teils des Truncus inferior",
#     "proximalTo": "RID47280",
#     "regionalPartOf": [
#       "RID47292",
#       "RID47274"
#     ]
#   }
# }
# {
#   "_id": "RID21429",
#   "preferredLabel": "trunk of posterior auricular nerve",
#   "synonyms": [
#     "posterior auricular neural trunk"
#   ],
#   "parent": "RID21425",
#   "radlexProperties": {
#     "fmaid": "80804",
#     "preferredNameGerman": "Truncus des Nervus auricularis posterior"
#   }
# }
# {
#   "_id": "RID14253",
#   "preferredLabel": "right posterior inferior nasal nerve",
#   "parent": "RID12064",
#   "radlexProperties": {
#     "branchOf": "RID14242",
#     "fmaid": "52824",
#     "preferredNameGerman": "rechter Nervus nasalis posterior inferior",
#     "regionalPartOf": "RID14242"
#   }
# }
# {
#   "_id": "RID217",
#   "preferredLabel": "renal sinus",
#   "synonyms": [
#     "sinus of kidney",
#     "sinus renalis",
#     "Nierensinus"
#   ],
#   "parent": "RID29528",
#   "radlexProperties": {
#     "constitutionalPartOf": "RID205",
#     "fmaid": "284412",
#     "partOf": "RID205",
#     "preferredNameGerman": "sinus renalis",
#     "radlexVersionOfClassChange": "3.14",
#     "synonymGerman": "Nierensinus"
#   }
# }
# {
#   "_id": "RID2176",
#   "preferredLabel": "fascia of flexor-pronator compartment of forearm",
#   "parent": "RID2172",
#   "radlexProperties": {
#     "partOf": "RID2107",
#     "preferredNameGerman": "Unterarmfaszie des Flexor-Pronatorkompartimentes"
#   }
# }
# {
#   "_id": "RID25183",
#   "preferredLabel": "descending branch of meningeal branch of second cervical nerve",
#   "parent": "RID25179",
#   "radlexProperties": {
#     "fmaid": "65716",
#     "preferredNameGerman": "Ramus descendens des Ramus meningeus des Nervus cervicalis II"
#   }
# }
# {
#   "_id": "RID921",
#   "preferredLabel": "splenic artery",
#   "synonyms": [
#     "arteria splenica",
#     "arteria lienalis",
#     "arteria splenica"
#   ],
#   "parent": "RID35950",
#   "definition": "The largest branch of the celiac trunk with distribution to the spleen, pancreas, stomach and greater omentum. [MeSH]",
#   "radlexProperties": {
#     "bloodSupplyOf": "RID86",
#     "branchOf": "RID906",
#     "fmaid": "14773",
#     "hasBranch": [
#       "RID922",
#       "RID924",
#       "RID926",
#       "RID925",
#       "RID923"
#     ],
#     "hasRegionalPart": [
#       "RID922",
#       "RID38132",
#       "RID38131",
#       "RID38123",
#       "RID38122",
#       "RID924",
#       "RID926",
#       "RID925",
#       "RID923",
#       "RID38133",
#       "RID13084",
#       "RID38130"
#     ],
#     "partOf": "RID13183",
#     "preferredNameGerman": "Arteria lienalis",
#     "regionalPartOf": "RID906",
#     "synonymGerman": "arteria splenica",
#     "umlsId": "C0037996"
#   }
# }
# {
#   "_id": "RID9210",
#   "preferredLabel": "frontal eminence of frontal bone",
#   "parent": "RID13238",
#   "radlexProperties": {
#     "partOf": "RID9209",
#     "preferredNameGerman": "Eminentia frontalis"
#   }
# }
# {
#   "_id": "RID9214",
#   "preferredLabel": "supraorbital foramen",
#   "parent": "RID34479",
#   "radlexProperties": {
#     "comment": "contains supraorbital nerve and vessels",
#     "partOf": "RID9213",
#     "preferredNameGerman": "Foramen supraorbitale"
#   }
# }
# {
#   "_id": "RID9211",
#   "preferredLabel": "superciliary arch of frontal bone",
#   "parent": "RID13238",
#   "radlexProperties": {
#     "partOf": "RID9209",
#     "preferredNameGerman": "Arcus superciliaris"
#   }
# }
# {
#   "_id": "RID46777",
#   "preferredLabel": "musculocutaneous nerve component of superior trunk segment of right fifth cervical nerve",
#   "synonyms": [
#     "musculocutaneous nerve component of superior trunk segment of right C5"
#   ],
#   "parent": "RID46776",
#   "radlexProperties": {
#     "constitutionalPartOf": "RID47982",
#     "continuousWith": [
#       "RID46780",
#       "RID46774"
#     ],
#     "distalTo": "RID46780",
#     "fmaid": "306860",
#     "preferredNameGerman": "zum Nervus musculocutaneus gehörender Teil des zum rechten Nervus cervicalis V gehörenden Teils des Truncus superior",
#     "proximalTo": "RID46774",
#     "regionalPartOf": "RID46771"
#   }
# }
# {
#   "_id": "RID48646",
#   "preferredLabel": "skin of posterior part of left ankle",
#   "parent": "RID48644",
#   "radlexProperties": {
#     "fmaid": "37872",
#     "preferredNameGerman": "Haut des hinteren Teils des linken Sprunggelenks"
#   }
# }
# {
#   "_id": "RID35846",
#   "preferredLabel": "subdivision of common carotid artery",
#   "synonyms": [
#     "common carotid arterial subdivision"
#   ],
#   "parent": "RID479",
#   "radlexProperties": {
#     "fmaid": "70504",
#     "preferredNameGerman": "Segment der Arteria carotis communis"
#   }
# }
# {
#   "_id": "RID34710",
#   "preferredLabel": "breast implant",
#   "parent": "RID28790",
#   "radlexProperties": {
#     "memberOf": "RID34297",
#     "preferredNameGerman": "Brustimplantat",
#     "radlexVersionOfClassChange": "09/22/2014",
#     "source": "BI-RADS 5, Playbook"
#   }
# }
# {
#   "_id": "RID1362",
#   "preferredLabel": "pleura",
#   "parent": "RID35857",
#   "definition": "The thin serous membrane enveloping the lungs (lung) and lining the thoracic cavity. Pleura consist of two layers, the inner visceral pleura lying next to the pulmonary parenchyma and the outer parietal pleura. Between the two layers is the pleural cavity which contains a thin film of liquid. [MeSH]",
#   "radlexProperties": {
#     "hasPart": [
#       "RID1363",
#       "RID1372"
#     ],
#     "partOf": "RID1243",
#     "preferredNameGerman": "Pleura",
#     "source": "Playbook",
#     "umlsId": "C0032225"
#   }
# }
# {
#   "_id": "RID1366",
#   "preferredLabel": "costal pleura",
#   "parent": "RID34910",
#   "radlexProperties": {
#     "preferredNameGerman": "Kostale Pleura"
#   }
# }
# {
#   "_id": "RID40501",
#   "preferredLabel": "common belly of right adductor pollicis",
#   "parent": "RID40500",
#   "radlexProperties": {
#     "fmaid": "65237",
#     "preferredNameGerman": "Bauch des rechten Musculus adductor pollicis"
#   }
# }
# {
#   "_id": "RID46511",
#   "preferredLabel": "c8 dorsal column nucleus of left medial pectoral nerve",
#   "parent": "RID46509",
#   "radlexProperties": {
#     "fmaid": "291702",
#     "preferredNameGerman": "Nucleus des linken Nervus pectoralis medialis in der Hintersäule des Segments C8",
#     "regionalPartOf": "RID47904"
#   }
# }
# {
#   "_id": "RID15351",
#   "preferredLabel": "compressor urethrae branch of left perineal nerve",
#   "parent": "RID15349",
#   "radlexProperties": {
#     "fmaid": "82944",
#     "preferredNameGerman": "Ramus des linken Nervus perinealis zum Musculus compressor urethrae"
#   }
# }
# {
#   "_id": "RID33035",
#   "preferredLabel": "perirenal fat",
#   "synonyms": [
#     "periphrenic fascia"
#   ],
#   "parent": "RID33033",
#   "radlexProperties": {
#     "fmaid": "20502",
#     "preferredNameGerman": "perirenales Fettgewebe"
#   }
# }

# %% [markdown]
# #### Code to check if "|" was removed from JSON docs

# %%
# check multiple docs if any instance of not transformed "|"
import json

docs = await collection.find({}).to_list(length=10)
for doc in docs:
    t_doc = transform_radlex(doc)
    t_doc_json = json.dumps(t_doc.dict())
    if "|" in t_doc_json:
        print(f"Error in transforming document {t_doc.id}: '|' character found.")

# %% [markdown]
# # Code to write transformed RadLex to new 'radlex' collection in MongoDB

# %%
doc = await collection.find_one()

print(doc)
# Out:
# {'_id': ObjectId('65f84ed1f80fad5323c79c1f'), 'Class ID': 'http://radlex.org/RID/RID35591', 'Preferred Label': 'string-of-pearls sign of bowel', 'Definitions': 'Oblique or horizontal row of air bubbles visible on abdominal radiograph; almost always indicates small bowel obstruction; air is trapped between valvulae conniventes along the superior wall of the intestine.', 'Obsolete': False, 'Parents': 'http://radlex.org/RID/RID29023', 'http://data': {'bioontology': {'org/metadata/prefixIRI': 'RID35591'}}, 'http://radlex': {'org/RID/Anatomical_Site': 'http://radlex.org/RID/RID132', 'org/RID/Comment': 'http://radiology.rsna.org/cgi/content/full/214/1/157', 'org/RID/Definition': 'Oblique or horizontal row of air bubbles visible on abdominal radiograph; almost always indicates small bowel obstruction; air is trapped between valvulae conniventes along the superior wall of the intestine.', 'org/RID/May_Be_Caused_By': 'http://radlex.org/RID/RID4962', 'org/RID/Preferred_name': 'string-of-pearls sign of bowel', 'org/RID/Preferred_name_German': 'string-of-pearls sign of bowel (EN)', 'org/RID/Related_modality': 'http://radlex.org/RID/RID10345', 'org/RID/Source': 'Radiology 2000; 214:157-158'}}

# %% [markdown]
# ## Demo fetch docs from 'RadLex' collection in batches of 100 => demo JSON dumps

# %% [markdown]
# #### This demos the function

# %%
async def fetch_and_demo_docs():
    # Fetch 10 documents
    docs = await collection.find({}).to_list(length=100)

    # Iterate through the documents
    for doc in docs:
        # Transform the document
        transformed_doc = transform_radlex(doc)

        # Print JSON dump of the transformed document
        print(transformed_doc.model_dump_json(indent=2, by_alias=True, exclude_none=True))


# Run the async function
await fetch_and_demo_docs()

# %%
from typing import AsyncGenerator

from motor.motor_asyncio import AsyncIOMotorCollection


async def get_documents_in_batches(
    collection: AsyncIOMotorCollection, batch_size: int = 100, limit: int | None = None, skip: int = 0
) -> AsyncGenerator[list[dict], None]:
    # Get the total count of documents in the collection
    total_count = limit if limit else await collection.count_documents({})
    print(f"Total count of documents in the collection: {total_count}")

    # Loop through the documents in batches
    while skip < total_count:
        # Fetch the documents in the current batch
        docs = await collection.find({}, skip=skip, limit=batch_size).to_list(length=batch_size)
        yield docs

        # Increment the skip variable by the batch size
        skip += batch_size

# %%
from pydantic import ValidationError

new_collection = db["radlex"]

async for docs in get_documents_in_batches(collection, batch_size=250, skip=24250):
    transformed_docs = []
    for doc in docs:
        try:
            transformed_docs.append(transform_radlex(doc))
        except ValidationError as e:
            print(f"Error transforming document {doc['_id']}: {e}")
            print(doc)
    await new_collection.insert_many([doc.model_dump(by_alias=True, exclude_none=True) for doc in transformed_docs])
    print(f"Inserted {len(transformed_docs)} documents into the new collection.")
# Out:
# Total count of documents in the collection: 46761
# Error transforming document 65f84ee1f80fad5323c7fb78: 1 validation error for RadLexConcept
# preferred_label
#   Input should be a valid string [type=string_type, input_value=False, input_type=bool]
#     For further information visit https://errors.pydantic.dev/2.6/v/string_type
# {'_id': ObjectId('65f84ee1f80fad5323c7fb78'), 'Class ID': 'http://radlex.org/RID/RID49835', 'Preferred Label': False, 'Obsolete': False, 'Parents': 'http://radlex.org/RID/RID49833', 'http://data': {'bioontology': {'org/metadata/prefixIRI': 'RID49835'}}, 'http://radlex': {'org/RID/Created': '2015-03-12T00:00:00', 'org/RID/Preferred_name': False, 'org/RID/Preferred_name_German': 'falsch', 'org/RID/Radlex_version_of_class_change': 3.13, 'org/RID/Source': 'Playbook'}}
# Inserted 249 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Error transforming document 65f84eedf80fad5323c83bb2: 1 validation error for RadLexConcept
# preferred_label
#   Input should be a valid string [type=string_type, input_value=True, input_type=bool]
#     For further information visit https://errors.pydantic.dev/2.6/v/string_type
# {'_id': ObjectId('65f84eedf80fad5323c83bb2'), 'Class ID': 'http://radlex.org/RID/RID49834', 'Preferred Label': True, 'Obsolete': False, 'Parents': 'http://radlex.org/RID/RID49833', 'http://data': {'bioontology': {'org/metadata/prefixIRI': 'RID49834'}}, 'http://radlex': {'org/RID/Created': '2015-03-12T00:00:00', 'org/RID/Preferred_name': True, 'org/RID/Preferred_name_German': 'echt', 'org/RID/Radlex_version_of_class_change': 3.13, 'org/RID/Source': 'Playbook'}}
# Inserted 249 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 250 documents into the new collection.
# Inserted 11 documents into the new collection.

# %%
from bson import ObjectId

true_false_docs = [
    {
        "_id": ObjectId("65f84eedf80fad5323c83bb2"),
        "Class ID": "http://radlex.org/RID/RID49834",
        "Preferred Label": "true",
        "Obsolete": False,
        "Parents": "http://radlex.org/RID/RID49833",
        "http://data": {"bioontology": {"org/metadata/prefixIRI": "RID49834"}},
        "http://radlex": {
            "org/RID/Created": "2015-03-12T00:00:00",
            "org/RID/Preferred_name": "true",
            "org/RID/Preferred_name_German": "echt",
            "org/RID/Radlex_version_of_class_change": 3.13,
            "org/RID/Source": "Playbook",
        },
    },
    {
        "_id": ObjectId("65f84ee1f80fad5323c7fb78"),
        "Class ID": "http://radlex.org/RID/RID49835",
        "Preferred Label": "false",
        "Obsolete": False,
        "Parents": "http://radlex.org/RID/RID49833",
        "http://data": {"bioontology": {"org/metadata/prefixIRI": "RID49835"}},
        "http://radlex": {
            "org/RID/Created": "2015-03-12T00:00:00",
            "org/RID/Preferred_name": "false",
            "org/RID/Preferred_name_German": "falsch",
            "org/RID/Radlex_version_of_class_change": 3.13,
            "org/RID/Source": "Playbook",
        },
    },
]

# %%
t_docs = [transform_radlex(doc) for doc in true_false_docs]
await new_collection.insert_many([doc.model_dump(by_alias=True, exclude_none=True) for doc in t_docs])
# Out:
# InsertManyResult(['RID49834', 'RID49835'], acknowledged=True)

# %% [markdown]
# ### Now run these scripts to access the new 'radlex' collection within the 'ontologies' database and then run batch script

# %%
# establish connection to MongoDB
config = dotenv_values(".env")
client = motor.motor_asyncio.AsyncIOMotorClient(config["ATLAS_DSN"])
db = client["ontologies"]


##### change to the new collection "radlex"
collection_new = db["radLex"]


# Get the count of documents in the collection to confirm that the data was loaded—should be zero before we load data
count = await collection.count_documents({})
print(f"Count of documents in the collection: {count}")
# Out:
# Count of documents in the collection: 0

# %%
# import the batch_transform_and_write_to_db function function
from openimagingdatamodel.ontology_tools import batch_transform_and_write_to_db

# %% [markdown]
# # Final Script to Write Transformed Documents to MongoDB `radlex` collection in `ontologies` database

# %%
async def fetch_transform_and_write_docs():
    # Fetch documents in batches of 100
    cursor = collection.find({}).batch_size(100)

    batch = []
    async for doc in cursor:
        # Transform the document
        transformed_doc = transform_radlex(doc)

        # Print JSON dump of the transformed document (demo)
        print(transformed_doc.model_dump_json(indent=2))

        # Add transformed document to the batch
        batch.append(transformed_doc.model_dump())

        # If the batch size reaches 100, write it to the database
        if len(batch) == 100:
            batch_transform_and_write_to_db(collection, batch)
            batch = []

    # Write any remaining documents in the last batch
    if batch:
        batch_transform_and_write_to_db(collection, batch)


# Run the async function
await fetch_transform_and_write_docs()

# %%
import json

from openimagingdatamodel.cde_set import CDESet, FindingModel, SetFactory

# %% [markdown]
# ## Confirm CDE Set definition

# %%
with open("openimagingdatamodel/cde_set/data/SampleDES.cde.json", "r") as file:
    cde_set_data = json.load(file)

# %%
set = CDESet.model_validate(cde_set_data)

# %%
print(set.model_dump_json(indent=2))
# Out:
# {
#   "id": "RDES3",
#   "name": "CAR/DS Adrenal Nodule",
#   "description": "ACR Assist project for describing adrenal nodules.",
#   "set_version": {
#     "number": 1,
#     "date": "2016-01-03"
#   },
#   "schema_version": "1.0.0",
#   "status": {
#     "date": "2016-01-03",
#     "name": "Proposed"
#   },
#   "url": null,
#   "index_codes": [],
#   "body_parts": null,
#   "contributors": {
#     "people": [
#       {
#         "name": "Tarik Alkasab",
#         "email": "talkasab@partners.org",
#         "affiliation": null,
#         "orcid_id": null,
#         "twitter_handle": null,
#         "url": null,
#         "role": "Author"
#       },
#       {
#         "name": "Marc Kohli",
#         "email": "marc.kohli@ucsf.edu",
#         "affiliation": "UCSF",
#         "orcid_id": "0000-0003-3720-0156",
#         "twitter_handle": null,
#         "url": null,
#         "role": "Editor"
#       }
#     ],
#     "organizations": [
#       {
#         "name": "American College of Radiology",
#         "url": null,
#         "abbreviation": "ACR",
#         "comment": null,
#         "role": null
#       }
#     ]
#   },
#   "history": [],
#   "specialties": [
#     {
#       "abbreviation": "AB",
#       "name": "Abdominal Radiology"
#     },
#     {
#       "abbreviation": "GU",
#       "name": "Genitourinary Radiology"
#     }
#   ],
#   "elements": [
#     {
#       "id": "RDE41",
#       "parent_set": "RDES3",
#       "name": "Nodule size",
#       "definition": "The greatest linear dimension of the adrenal nodule.",
#       "question": null,
#       "element_version": {
#         "number": 1,
#         "date": "2016-01-03"
#       },
#       "schema_version": "1.0.0",
#       "status": {
#         "date": "2016-01-03",
#         "name": "Proposed"
#       },
#       "index_codes": [
#         {
#           "system": "SNOMEDCT",
#           "code": "246120007",
#           "display": "nodule size",
#           "url": "http://snomed.info/sct"
#         }
#       ],
#       "contributors": null,
#       "history": null,
#       "specialties": null,
#       "references": null,
#       "source": null,
#       "integer_value": {
#         "min": 0,
#         "max": 999,
#         "step": 1,
#         "unit": "mm"
#       }
#     },
#     {
#       "id": "RDE42",
#       "parent_set": "RDES3",
#       "name": "Side",
#       "definition": "The side of the body (right or left)",
#       "question": null,
#       "element_version": {
#         "number": 1,
#         "date": "2016-01-03"
#       },
#       "schema_version": "1.0.0",
#       "status": {
#         "date": "2016-01-03",
#         "name": "Proposed"
#       },
#       "index_codes": null,
#       "contributors": null,
#       "history": null,
#       "specialties": null,
#       "references": null,
#       "source": null,
#       "value_set": {
#         "min_cardinality": 1,
#         "max_cardinality": 1,
#         "values": [
#           {
#             "code": "RDE42.0",
#             "value": "R",
#             "name": "Right",
#             "definition": null,
#             "index_codes": [
#               {
#                 "system": "RADLEX",
#                 "code": "RID5828",
#                 "display": "Right",
#                 "url": "http://radlex.org/"
#               },
#               {
#                 "system": "SNOMEDCT",
#                 "code": "24028007",
#                 "display": "Right",
#                 "url": "http://snomed.info/sct"
#               }
#             ],
#             "images": null
#           },
#           {
#             "code": "RDE42.1",
#             "value": "L",
#             "name": "Left",
#             "definition": null,
#             "index_codes": [
#               {
#                 "system": "RADLEX",
#                 "code": "RID5824",
#                 "display": "Left",
#                 "url": "http://radlex.org/"
#               },
#               {
#                 "system": "SNOMEDCT",
#                 "code": "7771000",
#                 "display": "Left",
#                 "url": "http://snomed.info/sct"
#               }
#             ],
#             "images": null
#           }
#         ]
#       }
#     },
#     {
#       "id": "RDE43",
#       "parent_set": "RDES3",
#       "name": "Unenhanced attenuation",
#       "definition": "Mean attenuation in Hounsfield units (HU) of the region of interest on CT images obtained without IV contrast.",
#       "question": "Enter the attenuation of the region of interest on the unenhnaced CT.",
#       "element_version": {
#         "number": 1,
#         "date": "2016-01-03"
#       },
#       "schema_version": "1.0.0",
#       "status": {
#         "date": "2016-01-03",
#         "name": "Published"
#       },
#       "index_codes": [
#         {
#           "system": "RADLEX",
#           "code": "RID28662",
#           "display": "Attenuation",
#           "url": "http://www.radlex.org/RID/RID28662"
#         },
#         {
#           "system": "RADLEX",
#           "code": "RID11086",
#           "display": "Unenhanced phase",
#           "url": "http://www.radlex.org/RID/RID11086"
#         }
#       ],
#       "contributors": {
#         "people": [],
#         "organizations": []
#       },
#       "history": [],
#       "specialties": null,
#       "references": [],
#       "source": null,
#       "integer_value": {
#         "min": -1024,
#         "max": 1024,
#         "step": 1,
#         "unit": "HU"
#       }
#     },
#     {
#       "id": "RDE44",
#       "parent_set": "RDES3",
#       "name": "Enhanced attenuation",
#       "definition": "Mean attenuation in Hounsfield units (HU) of the region of interest on CT images obtained immediately after IV contrast administration.",
#       "question": "",
#       "element_version": {
#         "number": 1,
#         "date": "2016-01-03"
#       },
#       "schema_version": "1.0.0",
#       "status": {
#         "date": "2016-01-03",
#         "name": "Published"
#       },
#       "index_codes": [],
#       "contributors": {
#         "people": [],
#         "organizations": []
#       },
#       "history": [],
#       "specialties": null,
#       "references": [],
#       "source": null,
#       "integer_value": {
#         "min": -1024,
#         "max": 1024,
#         "step": 1,
#         "unit": "HU"
#       }
#     },
#     {
#       "id": "RDE45",
#       "parent_set": "RDES3",
#       "name": "Delayed attenuation",
#       "definition": "Mean attenuation in Hounsfield units (HU) of the region of interest on CT images otained at least 3 min after IV contrast administration.",
#       "question": "Enter the attenuation of the region of interest on delayed CT images.",
#       "element_version": {
#         "number": 1,
#         "date": "2016-01-03"
#       },
#       "schema_version": "1.0.0",
#       "status": {
#         "date": "2016-01-03",
#         "name": "Published"
#       },
#       "index_codes": [
#         {
#           "system": "RADLEX",
#           "code": "RID28662",
#           "display": "Attenuation",
#           "url": "http://www.radlex.org/RID/RID28662"
#         },
#         {
#           "system": "RADLEX",
#           "code": "RID11081",
#           "display": "delayed phase",
#           "url": "http://www.radlex.org/RID/RID11081"
#         }
#       ],
#       "contributors": {
#         "people": [],
#         "organizations": []
#       },
#       "history": [],
#       "specialties": null,
#       "references": [],
#       "source": null,
#       "integer_value": {
#         "min": -1024,
#         "max": 1024,
#         "step": 1,
#         "unit": "HU"
#       }
#     },
#     {
#       "id": "RDE49",
#       "parent_set": "RDES3",
#       "name": "Uniformly cystic",
#       "definition": "Indicates if the adrenal nodule is uniformly cystic. ",
#       "question": "Is the adrenal nodule uniformly cystic?",
#       "element_version": {
#         "number": 1,
#         "date": "2016-01-03"
#       },
#       "schema_version": "1.0.0",
#       "status": {
#         "date": "2016-01-03",
#         "name": "Proposed"
#       },
#       "index_codes": [],
#       "contributors": {
#         "people": [],
#         "organizations": []
#       },
#       "history": [],
#       "specialties": null,
#       "references": [],
#       "source": null,
#       "boolean_value": "boolean"
#     },
#     {
#       "id": "RDE42",
#       "parent_set": "RDES3",
#       "name": "Side",
#       "definition": "The side of the body (right or left).",
#       "question": "",
#       "element_version": {
#         "number": 1,
#         "date": "2016-01-03"
#       },
#       "schema_version": "1.0.0",
#       "status": {
#         "date": "2016-01-03",
#         "name": "Proposed"
#       },
#       "index_codes": [
#         {
#           "system": "RADLEX",
#           "code": "RID5824",
#           "display": "Left",
#           "url": "http://www.radlex.org/RID/RID5824"
#         },
#         {
#           "system": "RADLEX",
#           "code": "RID5825",
#           "display": "Right",
#           "url": "http://www.radlex.org/RID/RID5825"
#         },
#         {
#           "system": "SNOMEDCT",
#           "code": "7771000",
#           "display": "Left",
#           "url": "http://purl.bioontology.org/ontology/SNOMEDCT/7771000"
#         },
#         {
#           "system": "SNOMEDCT",
#           "code": "24028007",
#           "display": "Right",
#           "url": "http://purl.bioontology.org/ontology/SNOMEDCT/24028007"
#         },
#         {
#           "system": "SNOMEDCT",
#           "code": "272741003",
#           "display": "Laterality",
#           "url": "http://purl.bioontology.org/ontology/SNOMEDCT/272741003"
#         },
#         {
#           "system": "RADLEX",
#           "code": "RID5821",
#           "display": "laterality",
#           "url": "http://www.radlex.org/RID/RID5821"
#         }
#       ],
#       "contributors": {
#         "people": [],
#         "organizations": []
#       },
#       "history": [],
#       "specialties": null,
#       "references": [],
#       "source": null,
#       "value_set": {
#         "min_cardinality": 1,
#         "max_cardinality": 1,
#         "values": [
#           {
#             "code": "RDE42.0",
#             "value": "R",
#             "name": "Right",
#             "definition": null,
#             "index_codes": null,
#             "images": null
#           },
#           {
#             "code": "RDE42.1",
#             "value": "L",
#             "name": "Left",
#             "definition": null,
#             "index_codes": null,
#             "images": null
#           }
#         ]
#       }
#     },
#     {
#       "id": "RDE1695",
#       "parent_set": "RDES3",
#       "name": "Microscopic fat",
#       "definition": "The adrenal nodule contains macroscopic fat, as evidenced by at least one pixel attenuation value less than -10 HU.",
#       "question": null,
#       "element_version": {
#         "number": 1,
#         "date": "2023-06-23"
#       },
#       "schema_version": "1.0.0",
#       "status": {
#         "date": "2023-06-23",
#         "name": "Published"
#       },
#       "index_codes": [],
#       "contributors": {
#         "people": [],
#         "organizations": []
#       },
#       "history": [],
#       "specialties": null,
#       "references": [],
#       "source": null,
#       "value_set": {
#         "min_cardinality": 1,
#         "max_cardinality": 1,
#         "values": [
#           {
#             "code": "RDE1695.0",
#             "value": null,
#             "name": "present",
#             "definition": null,
#             "index_codes": null,
#             "images": null
#           },
#           {
#             "code": "RDE1695.1",
#             "value": null,
#             "name": "absent",
#             "definition": null,
#             "index_codes": null,
#             "images": null
#           },
#           {
#             "code": "RDE1695.2",
#             "value": null,
#             "name": "unknown",
#             "definition": null,
#             "index_codes": null,
#             "images": null
#           },
#           {
#             "code": "RDE1695.2",
#             "value": null,
#             "name": "indeterminate",
#             "definition": null,
#             "index_codes": null,
#             "images": null
#           }
#         ]
#       }
#     }
#   ],
#   "references": [
#     {
#       "citation": "Sangwaiya MJ, Boland GW, Cronin CG et-al. Incidental adrenal lesions: accuracy of characterization with contrast-enhanced washout multidetector CT-10-minute delayed imaging protocol revisited in a large patient cohort. Radiology. 2010;256 (2): 504-10.",
#       "doi_uri": null,
#       "pubmed_id": "20656838",
#       "url": null
#     },
#     {
#       "citation": "Blake MA, Cronin CG, Boland GW. Adrenal imaging. AJR Am J Roentgenol. 2010;194 (6):1450-60.",
#       "doi_uri": null,
#       "pubmed_id": "20489083",
#       "url": null
#     }
#   ]
# }

# %% [markdown]
# ## Set Factory Tools

# %%
set = SetFactory.create_set("healed rib fracture", add_presence_element=True)

# %%
print(set.model_dump_json(exclude_none=True, indent=2))
# Out:
# {
#   "id": "TO_BE_DETERMINED8026",
#   "name": "healed rib fracture",
#   "description": "Description for healed rib fracture",
#   "set_version": {
#     "number": 1,
#     "date": "2024-04-02"
#   },
#   "schema_version": "1.0.0",
#   "status": {
#     "date": "2024-04-02",
#     "name": "Proposed"
#   },
#   "index_codes": [],
#   "history": [
#     {
#       "date": "2024-04-02",
#       "status": {
#         "date": "2024-04-02",
#         "name": "Proposed"
#       }
#     }
#   ],
#   "specialties": [],
#   "elements": [
#     {
#       "id": "TO_BE_DETERMINED5596",
#       "name": "Presence of healed rib fracture",
#       "definition": "Presence of healed rib fracture",
#       "question": "Is the healed rib fracture present?",
#       "element_version": {
#         "number": 1,
#         "date": "2024-04-02"
#       },
#       "schema_version": "1.0.0",
#       "status": {
#         "date": "2024-04-02",
#         "name": "Proposed"
#       },
#       "value_set": {
#         "min_cardinality": 1,
#         "max_cardinality": 1,
#         "values": [
#           {
#             "code": "TO_BE_DETERMINED5596.0",
#             "value": "absent",
#             "name": "Absent"
#           },
#           {
#             "code": "TO_BE_DETERMINED5596.1",
#             "value": "present",
#             "name": "Present"
#           },
#           {
#             "code": "TO_BE_DETERMINED5596.2",
#             "value": "unknown",
#             "name": "Unknown"
#           },
#           {
#             "code": "TO_BE_DETERMINED5596.3",
#             "value": "indetermiante",
#             "name": "Indetermiante"
#           }
#         ]
#       }
#     }
#   ]
# }

# %%
int_el = SetFactory.create_integer_element("age", min=0, max=120, unit="years")
print(int_el.model_dump_json(exclude_none=True, indent=2))
# Out:
# {
#   "id": "TO_BE_DETERMINED1440",
#   "name": "age",
#   "element_version": {
#     "number": 1,
#     "date": "2024-04-02"
#   },
#   "schema_version": "1.0.0",
#   "status": {
#     "date": "2024-04-02",
#     "name": "Proposed"
#   },
#   "integer_value": {
#     "min": 0,
#     "max": 120,
#     "unit": "years"
#   }
# }

# %%
float_el = SetFactory.create_float_element("size", min=0, max=50, unit="mm")
print(int_el.model_dump_json(exclude_none=True, indent=2))
# Out:
# {
#   "id": "TO_BE_DETERMINED1440",
#   "name": "age",
#   "element_version": {
#     "number": 1,
#     "date": "2024-04-02"
#   },
#   "schema_version": "1.0.0",
#   "status": {
#     "date": "2024-04-02",
#     "name": "Proposed"
#   },
#   "integer_value": {
#     "min": 0,
#     "max": 120,
#     "unit": "years"
#   }
# }

# %%
bool_el = SetFactory.create_boolean_element("count")
print(bool_el.model_dump_json(exclude_none=True, indent=2))
# Out:
# {
#   "id": "TO_BE_DETERMINED8871",
#   "name": "count",
#   "element_version": {
#     "number": 1,
#     "date": "2024-04-02"
#   },
#   "schema_version": "1.0.0",
#   "status": {
#     "date": "2024-04-02",
#     "name": "Proposed"
#   },
#   "boolean_value": "boolean"
# }

# %%
values = ["bar", "baz", "qux"]

value_set_el = SetFactory.create_value_set_element("Foo", values)
print(value_set_el.model_dump_json(exclude_none=True, indent=2))
# Out:
# {
#   "id": "TO_BE_DETERMINED3871",
#   "name": "Foo",
#   "element_version": {
#     "number": 1,
#     "date": "2024-04-02"
#   },
#   "schema_version": "1.0.0",
#   "status": {
#     "date": "2024-04-02",
#     "name": "Proposed"
#   },
#   "value_set": {
#     "min_cardinality": 1,
#     "max_cardinality": 1,
#     "values": [
#       {
#         "code": "TO_BE_DETERMINED3871.0",
#         "name": "bar"
#       },
#       {
#         "code": "TO_BE_DETERMINED3871.1",
#         "name": "baz"
#       },
#       {
#         "code": "TO_BE_DETERMINED3871.2",
#         "name": "qux"
#       }
#     ]
#   }
# }

# %%
# Add elements to the set
set.elements.extend([int_el, float_el, bool_el, value_set_el])
print(set.model_dump_json(exclude_none=True, indent=2))
# Out:
# {
#   "id": "TO_BE_DETERMINED1553",
#   "name": "healed rib fracture",
#   "description": "Description for healed rib fracture",
#   "set_version": {
#     "number": 1,
#     "date": "2024-04-01"
#   },
#   "schema_version": "1.0.0",
#   "status": {
#     "date": "2024-04-01",
#     "name": "Proposed"
#   },
#   "index_codes": [],
#   "history": [
#     {
#       "date": "2024-04-01",
#       "status": {
#         "date": "2024-04-01",
#         "name": "Proposed"
#       }
#     }
#   ],
#   "specialties": [],
#   "elements": [
#     {
#       "id": "TO_BE_DETERMINED2893",
#       "name": "Presence of healed rib fracture",
#       "definition": "Presence of healed rib fracture",
#       "question": "Is the healed rib fracture present?",
#       "element_version": {
#         "number": 1,
#         "date": "2024-04-01"
#       },
#       "schema_version": "1.0.0",
#       "status": {
#         "date": "2024-04-01",
#         "name": "Proposed"
#       },
#       "value_set": {
#         "min_cardinality": 1,
#         "max_cardinality": 1,
#         "values": [
#           {
#             "code": "TO_BE_DETERMINED2893.0",
#             "value": "absent",
#             "name": "Absent"
#           },
#           {
#             "code": "TO_BE_DETERMINED2893.1",
#             "value": "present",
#             "name": "Present"
#           },
#           {
#             "code": "TO_BE_DETERMINED2893.2",
#             "value": "unknown",
#             "name": "Unknown"
#           },
#           {
#             "code": "TO_BE_DETERMINED2893.3",
#             "value": "indetermiante",
#             "name": "Indetermiante"
#           }
#         ]
#       }
#     },
#     {
#       "id": "TO_BE_DETERMINED8878",
#       "name": "age",
#       "element_version": {
#         "number": 1,
#         "date": "2024-04-01"
#       },
#       "schema_version": "1.0.0",
#       "status": {
#         "date": "2024-04-01",
#         "name": "Proposed"
#       },
#       "integer_value": {
#         "min": 0,
#         "max": 120,
#         "unit": "years"
#       }
#     },
#     {
#       "id": "TO_BE_DETERMINED0891",
#       "name": "size",
#       "element_version": {
#         "number": 1,
#         "date": "2024-04-01"
#       },
#       "schema_version": "1.0.0",
#       "status": {
#         "date": "2024-04-01",
#         "name": "Proposed"
#       },
#       "float_value": {
#         "min": 0.0,
#         "max": 50.0,
#         "unit": "mm"
#       }
#     },
#     {
#       "id": "TO_BE_DETERMINED0426",
#       "name": "count",
#       "element_version": {
#         "number": 1,
#         "date": "2024-04-01"
#       },
#       "schema_version": "1.0.0",
#       "status": {
#         "date": "2024-04-01",
#         "name": "Proposed"
#       },
#       "boolean_value": "boolean"
#     },
#     {
#       "id": "TO_BE_DETERMINED9254",
#       "name": "Foo",
#       "element_version": {
#         "number": 1,
#         "date": "2024-04-01"
#       },
#       "schema_version": "1.0.0",
#       "status": {
#         "date": "2024-04-01",
#         "name": "Proposed"
#       },
#       "value_set": {
#         "min_cardinality": 1,
#         "max_cardinality": 1,
#         "values": [
#           {
#             "code": "TO_BE_DETERMINED9254.0",
#             "name": "bar"
#           },
#           {
#             "code": "TO_BE_DETERMINED9254.1",
#             "name": "baz"
#           },
#           {
#             "code": "TO_BE_DETERMINED9254.2",
#             "name": "qux"
#           }
#         ]
#       }
#     }
#   ]
# }

# %% [markdown]
# ## Finding Model

# %%
with open("openimagingdatamodel/cde_set/data/ipmn.json", "r") as file:
    finding_model_data = json.load(file)

finding_model: FindingModel = FindingModel.model_validate(finding_model_data)

# %%
def create_set_from_finding_model(model: FindingModel) -> CDESet:
    set: CDESet = SetFactory.create_set(model.finding_name)
    set.description = model.description
    for element in model.attributes:
        if element.type == "choice":
            values = [value.model_dump() for value in element.values]
            new_el = SetFactory.create_value_set_element(element.name, values)
            for el_value, att_value in zip(new_el.value_set.values, values):
                if description := att_value.get("description"):
                    el_value.definition = description
        if element.type == "numeric":
            new_el = SetFactory.create_float_element(
                element.name, min=element.minimum, max=element.maximum, unit=element.unit
            )
        if element.description:
            new_el.definition = element.description
        set.elements.append(new_el)
    return set

# %%
[value.model_dump() for value in finding_model.attributes[0].values]
# Out:
# [{'name': 'Present', 'description': 'IPMN is present in the pancreas.'},
#  {'name': 'Absent', 'description': 'IPMN is not present in the pancreas.'}]

# %%
ipmn_set = SetFactory.create_set_from_finding_model(finding_model)

# %%
print(ipmn_set.model_dump_json(exclude_none=True, indent=2))
# Out:
# {
#   "id": "TO_BE_DETERMINED6056",
#   "name": "ipmn",
#   "description": "Intraductal papillary mucinous neoplasm (IPMN) is a type of cystic lesion of the pancreas that is characterized by the presence of mucin-producing cells within the pancreatic ductal system.",
#   "set_version": {
#     "number": 1,
#     "date": "2024-04-02"
#   },
#   "schema_version": "1.0.0",
#   "status": {
#     "date": "2024-04-02",
#     "name": "Proposed"
#   },
#   "index_codes": [],
#   "history": [
#     {
#       "date": "2024-04-02",
#       "status": {
#         "date": "2024-04-02",
#         "name": "Proposed"
#       }
#     }
#   ],
#   "specialties": [],
#   "elements": [
#     {
#       "id": "TO_BE_DETERMINED0639",
#       "name": "Presence",
#       "definition": "Presence of IPMN in the pancreas.",
#       "element_version": {
#         "number": 1,
#         "date": "2024-04-02"
#       },
#       "schema_version": "1.0.0",
#       "status": {
#         "date": "2024-04-02",
#         "name": "Proposed"
#       },
#       "value_set": {
#         "min_cardinality": 1,
#         "max_cardinality": 1,
#         "values": [
#           {
#             "code": "TO_BE_DETERMINED0639.0",
#             "name": "Present",
#             "definition": "IPMN is present in the pancreas."
#           },
#           {
#             "code": "TO_BE_DETERMINED0639.1",
#             "name": "Absent",
#             "definition": "IPMN is not present in the pancreas."
#           }
#         ]
#       }
#     },
#     {
#       "id": "TO_BE_DETERMINED3701",
#       "name": "Status",
#       "definition": "Status of the IPMN.",
#       "element_version": {
#         "number": 1,
#         "date": "2024-04-02"
#       },
#       "schema_version": "1.0.0",
#       "status": {
#         "date": "2024-04-02",
#         "name": "Proposed"
#       },
#       "value_set": {
#         "min_cardinality": 1,
#         "max_cardinality": 1,
#         "values": [
#           {
#             "code": "TO_BE_DETERMINED3701.0",
#             "name": "New suspected",
#             "definition": "There is a new suspected IPMN."
#           },
#           {
#             "code": "TO_BE_DETERMINED3701.1",
#             "name": "Stable",
#             "definition": "The IPMN is stable."
#           },
#           {
#             "code": "TO_BE_DETERMINED3701.2",
#             "name": "Enlarging",
#             "definition": "The IPMN is enlarging."
#           }
#         ]
#       }
#     },
#     {
#       "id": "TO_BE_DETERMINED7269",
#       "name": "Type",
#       "definition": "Type of IPMN.",
#       "element_version": {
#         "number": 1,
#         "date": "2024-04-02"
#       },
#       "schema_version": "1.0.0",
#       "status": {
#         "date": "2024-04-02",
#         "name": "Proposed"
#       },
#       "value_set": {
#         "min_cardinality": 1,
#         "max_cardinality": 1,
#         "values": [
#           {
#             "code": "TO_BE_DETERMINED7269.0",
#             "name": "Main duct",
#             "definition": "IPMN is located in the main pancreatic duct."
#           },
#           {
#             "code": "TO_BE_DETERMINED7269.1",
#             "name": "Branch duct",
#             "definition": "IPMN is located in a branch pancreatic duct."
#           },
#           {
#             "code": "TO_BE_DETERMINED7269.2",
#             "name": "Mixed",
#             "definition": "IPMN is located in both main duct and branch ducts."
#           }
#         ]
#       }
#     },
#     {
#       "id": "TO_BE_DETERMINED7943",
#       "name": "Communication with Pancreatic Duct",
#       "definition": "Presence of communication between the IPMN and the pancreatic duct.",
#       "element_version": {
#         "number": 1,
#         "date": "2024-04-02"
#       },
#       "schema_version": "1.0.0",
#       "status": {
#         "date": "2024-04-02",
#         "name": "Proposed"
#       },
#       "value_set": {
#         "min_cardinality": 1,
#         "max_cardinality": 1,
#         "values": [
#           {
#             "code": "TO_BE_DETERMINED7943.0",
#             "name": "Present",
#             "definition": "There is communication between the IPMN and the pancreatic duct."
#           },
#           {
#             "code": "TO_BE_DETERMINED7943.1",
#             "name": "Absent",
#             "definition": "There is no communication between the IPMN and the pancreatic duct."
#           }
#         ]
#       }
#     },
#     {
#       "id": "TO_BE_DETERMINED7947",
#       "name": "Location in Pancreas",
#       "definition": "Location of the IPMN within the pancreas.",
#       "element_version": {
#         "number": 1,
#         "date": "2024-04-02"
#       },
#       "schema_version": "1.0.0",
#       "status": {
#         "date": "2024-04-02",
#         "name": "Proposed"
#       },
#       "value_set": {
#         "min_cardinality": 1,
#         "max_cardinality": 1,
#         "values": [
#           {
#             "code": "TO_BE_DETERMINED7947.0",
#             "name": "Uncinate",
#             "definition": "IPMN is located in the uncinate process of the pancreas."
#           },
#           {
#             "code": "TO_BE_DETERMINED7947.1",
#             "name": "Head",
#             "definition": "IPMN is located in the head of the pancreas."
#           },
#           {
#             "code": "TO_BE_DETERMINED7947.2",
#             "name": "Body",
#             "definition": "IPMN is located in the body of the pancreas."
#           },
#           {
#             "code": "TO_BE_DETERMINED7947.3",
#             "name": "Tail",
#             "definition": "IPMN is located in the tail of the pancreas."
#           }
#         ]
#       }
#     },
#     {
#       "id": "TO_BE_DETERMINED3387",
#       "name": "Size",
#       "definition": "Size of the IPMN in millimeters.",
#       "element_version": {
#         "number": 1,
#         "date": "2024-04-02"
#       },
#       "schema_version": "1.0.0",
#       "status": {
#         "date": "2024-04-02",
#         "name": "Proposed"
#       },
#       "float_value": {
#         "unit": "mm"
#       }
#     },
#     {
#       "id": "TO_BE_DETERMINED4434",
#       "name": "Number of Cysts",
#       "definition": "Number of cysts associated with the IPMN.",
#       "element_version": {
#         "number": 1,
#         "date": "2024-04-02"
#       },
#       "schema_version": "1.0.0",
#       "status": {
#         "date": "2024-04-02",
#         "name": "Proposed"
#       },
#       "value_set": {
#         "min_cardinality": 1,
#         "max_cardinality": 1,
#         "values": [
#           {
#             "code": "TO_BE_DETERMINED4434.0",
#             "name": "Single",
#             "definition": "There is a single cyst associated with the IPMN."
#           },
#           {
#             "code": "TO_BE_DETERMINED4434.1",
#             "name": "Multiple",
#             "definition": "There are multiple cysts associated with the IPMN."
#           }
#         ]
#       }
#     },
#     {
#       "id": "TO_BE_DETERMINED8737",
#       "name": "Main Pancreatic Ductal Dilation",
#       "definition": "Presence of main pancreatic ductal dilation.",
#       "element_version": {
#         "number": 1,
#         "date": "2024-04-02"
#       },
#       "schema_version": "1.0.0",
#       "status": {
#         "date": "2024-04-02",
#         "name": "Proposed"
#       },
#       "value_set": {
#         "min_cardinality": 1,
#         "max_cardinality": 1,
#         "values": [
#           {
#             "code": "TO_BE_DETERMINED8737.0",
#             "name": "Present",
#             "definition": "There is main pancreatic ductal dilation."
#           },
#           {
#             "code": "TO_BE_DETERMINED8737.1",
#             "name": "Absent",
#             "definition": "There is no main pancreatic ductal dilation."
#           }
#         ]
#       }
#     }
#   ]
# }

# %%
with open("ipmn.cde.json", "w") as file:
    file.write(ipmn_set.model_dump_json(exclude_none=True, indent=2))
